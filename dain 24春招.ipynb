# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor

# 加载MNIST数据集
training_data = datasets.MNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
)

test_data = datasets.MNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor(),
)

#计算指标
def compute_metrics(preds, labels, num_classes):
    # 初始化混淆矩阵
    confusion_matrix = torch.zeros(num_classes, num_classes)
    for p, l in zip(preds, labels):
        confusion_matrix[l, p] += 1

    # 计算每个类的精确率和召回率
    precision = torch.diag(confusion_matrix) / confusion_matrix.sum(0)
    recall = torch.diag(confusion_matrix) / confusion_matrix.sum(1)

    # 计算F1-Score
    f1 = 2 * precision * recall / (precision + recall)

    # 计算总的准确率
    accuracy = torch.diag(confusion_matrix).sum() / confusion_matrix.sum()

    # 因为可能存在分母为0的情况，我们需要处理NaN值
    precision[precision != precision] = 0  # 将NaN替换为0
    recall[recall != recall] = 0
    f1[f1 != f1] = 0

    # 计算平均值
    precision_mean = precision.mean().item()
    recall_mean = recall.mean().item()
    f1_mean = f1.mean().item()

    return accuracy.item(), precision_mean, recall_mean, f1_mean

# 创建数据加载器
batch_size = 64
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")

# 定义模型
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 128),  # 第一层，将28x28的图片展平后输入，输出128个节点
            nn.ReLU(),
            nn.Linear(128, 256),  # 第二层，接收第一层的128个节点，输出256个节点
            nn.ReLU(),
            nn.Linear(256, 10)  # 最后一层，输出10个节点，对应10个类别
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork()

# 定义损失函数和优化器
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)

# 训练过程
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        # 计算预测误差
        pred = model(X)
        loss = loss_fn(pred, y)

        # 反向传播
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
    return loss

# 测试过程
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss= 0
    accuracy_all, precision_all, recall_all, f1_all = 0, 0, 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            pred = torch.argmax(pred, dim=1)
            accuracy, precision_mean, recall_mean, f1_mean = compute_metrics(pred, y, num_classes=10)
            accuracy_all += accuracy
            precision_all += precision_mean
            recall_all += recall_mean
            f1_all += f1_mean
    test_loss /= num_batches
    accuracy_all /= num_batches
    precision_all /= num_batches
    recall_all /= num_batches
    f1_all /= num_batches
    print(f"Test Error: \n Accuracy: {(100*accuracy_all):>0.1f}%, Precision: {(100*precision_all):>0.1f}%, Recall: {(100*recall_all):>0.1f}%, F1: {(100*f1_all):>0.1f}%, Avg loss: {test_loss:>8f} \n")
    return test_loss, accuracy_all, precision_all, recall_all, f1_all

# 训练模型
epochs = 100
train_losses = []
test_losses = []
accuracy_all = []
precision_all = []
recall_all = []
f1_all = []
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loss=train(train_dataloader, model, loss_fn, optimizer)
    test_loss,accuracy,precision,recall,f1=test(test_dataloader, model, loss_fn)
    # 将trian_loss和test_loss转换为numpy类型
    train_loss = train_loss.cpu().detach().numpy()
    # 收集每个epoch的训练损失和测试损失
    train_losses.append(train_loss)
    test_losses.append(test_loss)
    accuracy_all.append(accuracy)
    precision_all.append(precision)
    recall_all.append(recall)
    f1_all.append(f1)

# 绘出指标变化图
import matplotlib.pyplot as plt
epochs = range(1, len(train_losses) + 1)

plt.figure(figsize=(10, 6))

plt.plot(epochs, accuracy_all, label='Accuracy', marker='o', linestyle='-')
plt.plot(epochs, precision_all, label='Precision', marker='s', linestyle='--')
plt.plot(epochs, recall_all, label='Recall', marker='^', linestyle='-.')
plt.plot(epochs, f1_all, label='F1 Score', marker='*', linestyle=':')

plt.title('Model Performance Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Metric')
plt.legend()
plt.grid(True)
plt.show()


# 绘出损失变化图
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_losses, label='Train')
plt.plot(epochs, test_losses, label='Test')
plt.title('Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

print("Done!")
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# <urlopen error [Errno 11001] getaddrinfo failed>
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to data\MNIST\raw\train-images-idx3-ubyte.gz
# 100%|████████████████████████████████████████████████████████████████████| 9912422/9912422 [00:10<00:00, 906956.82it/s]
# Extracting data\MNIST\raw\train-images-idx3-ubyte.gz to data\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to data\MNIST\raw\train-labels-idx1-ubyte.gz
# 100%|████████████████████████████████████████████████████████████████████████| 28881/28881 [00:00<00:00, 110747.47it/s]
# Extracting data\MNIST\raw\train-labels-idx1-ubyte.gz to data\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to data\MNIST\raw\t10k-images-idx3-ubyte.gz
# 100%|████████████████████████████████████████████████████████████████████| 1648877/1648877 [00:06<00:00, 265930.85it/s]
# Extracting data\MNIST\raw\t10k-images-idx3-ubyte.gz to data\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to data\MNIST\raw\t10k-labels-idx1-ubyte.gz
# 100%|█████████████████████████████████████████████████████████████████████████| 4542/4542 [00:00<00:00, 4804673.08it/s]
# Extracting data\MNIST\raw\t10k-labels-idx1-ubyte.gz to data\MNIST\raw
#
# Using cuda device
# Epoch 1
# -------------------------------
# loss: 2.295841  [    0/60000]
# loss: 2.286674  [ 6400/60000]
# loss: 2.302670  [12800/60000]
# loss: 2.284371  [19200/60000]
# loss: 2.297394  [25600/60000]
# loss: 2.282132  [32000/60000]
# loss: 2.277390  [38400/60000]
# loss: 2.290689  [44800/60000]
# loss: 2.274074  [51200/60000]
# loss: 2.266286  [57600/60000]
# Test Error:
#  Accuracy: 29.3%, Precision: 17.0%, Recall: 28.3%, F1: 18.7%, Avg loss: 2.266545
#
# Epoch 2
# -------------------------------
# loss: 2.261373  [    0/60000]
# loss: 2.249575  [ 6400/60000]
# loss: 2.273976  [12800/60000]
# loss: 2.234518  [19200/60000]
# loss: 2.258641  [25600/60000]
# loss: 2.242768  [32000/60000]
# loss: 2.226026  [38400/60000]
# loss: 2.250365  [44800/60000]
# loss: 2.221635  [51200/60000]
# loss: 2.206884  [57600/60000]
# Test Error:
#  Accuracy: 36.2%, Precision: 24.7%, Recall: 35.1%, F1: 23.7%, Avg loss: 2.208942
#
# Epoch 3
# -------------------------------
# loss: 2.202456  [    0/60000]
# loss: 2.186337  [ 6400/60000]
# loss: 2.224898  [12800/60000]
# loss: 2.151077  [19200/60000]
# loss: 2.193094  [25600/60000]
# loss: 2.173986  [32000/60000]
# loss: 2.132873  [38400/60000]
# loss: 2.178152  [44800/60000]
# loss: 2.126032  [51200/60000]
# loss: 2.102652  [57600/60000]
# Test Error:
#  Accuracy: 46.7%, Precision: 50.7%, Recall: 45.7%, F1: 38.9%, Avg loss: 2.106206
#
# Epoch 4
# -------------------------------
# loss: 2.096089  [    0/60000]
# loss: 2.072454  [ 6400/60000]
# loss: 2.136313  [12800/60000]
# loss: 2.011555  [19200/60000]
# loss: 2.074692  [25600/60000]
# loss: 2.049105  [32000/60000]
# loss: 1.977202  [38400/60000]
# loss: 2.053677  [44800/60000]
# loss: 1.965799  [51200/60000]
# loss: 1.933290  [57600/60000]
# Test Error:
#  Accuracy: 60.5%, Precision: 61.6%, Recall: 59.3%, F1: 54.9%, Avg loss: 1.936974
#
# Epoch 5
# -------------------------------
# loss: 1.925555  [    0/60000]
# loss: 1.885446  [ 6400/60000]
# loss: 1.985531  [12800/60000]
# loss: 1.802970  [19200/60000]
# loss: 1.873528  [25600/60000]
# loss: 1.841880  [32000/60000]
# loss: 1.751597  [38400/60000]
# loss: 1.862609  [44800/60000]
# loss: 1.731331  [51200/60000]
# loss: 1.693113  [57600/60000]
# Test Error:
#  Accuracy: 67.7%, Precision: 64.4%, Recall: 66.6%, F1: 62.2%, Avg loss: 1.691955
#
# Epoch 6
# -------------------------------
# loss: 1.688904  [    0/60000]
# loss: 1.622898  [ 6400/60000]
# loss: 1.752152  [12800/60000]
# loss: 1.537001  [19200/60000]
# loss: 1.590876  [25600/60000]
# loss: 1.561846  [32000/60000]
# loss: 1.473069  [38400/60000]
# loss: 1.611874  [44800/60000]
# loss: 1.454672  [51200/60000]
# loss: 1.413796  [57600/60000]
# Test Error:
#  Accuracy: 71.2%, Precision: 69.0%, Recall: 70.2%, F1: 66.3%, Avg loss: 1.409471
#
# Epoch 7
# -------------------------------
# loss: 1.424503  [    0/60000]
# loss: 1.336465  [ 6400/60000]
# loss: 1.471013  [12800/60000]
# loss: 1.273623  [19200/60000]
# loss: 1.305842  [25600/60000]
# loss: 1.278645  [32000/60000]
# loss: 1.205650  [38400/60000]
# loss: 1.354950  [44800/60000]
# loss: 1.204779  [51200/60000]
# loss: 1.167571  [57600/60000]
# Test Error:
#  Accuracy: 74.8%, Precision: 75.0%, Recall: 73.9%, F1: 71.3%, Avg loss: 1.163631
#
# Epoch 8
# -------------------------------
# loss: 1.201450  [    0/60000]
# loss: 1.099312  [ 6400/60000]
# loss: 1.220018  [12800/60000]
# loss: 1.064136  [19200/60000]
# loss: 1.084450  [25600/60000]
# loss: 1.051437  [32000/60000]
# loss: 0.998526  [38400/60000]
# loss: 1.143088  [44800/60000]
# loss: 1.015072  [51200/60000]
# loss: 0.984770  [57600/60000]
# Test Error:
#  Accuracy: 77.6%, Precision: 78.1%, Recall: 76.9%, F1: 75.1%, Avg loss: 0.979494
#
# Epoch 9
# -------------------------------
# loss: 1.037707  [    0/60000]
# loss: 0.927020  [ 6400/60000]
# loss: 1.026141  [12800/60000]
# loss: 0.910579  [19200/60000]
# loss: 0.923416  [25600/60000]
# loss: 0.884598  [32000/60000]
# loss: 0.848611  [38400/60000]
# loss: 0.982430  [44800/60000]
# loss: 0.878217  [51200/60000]
# loss: 0.855091  [57600/60000]
# Test Error:
#  Accuracy: 79.4%, Precision: 79.7%, Recall: 78.8%, F1: 77.2%, Avg loss: 0.844840
#
# Epoch 10
# -------------------------------
# loss: 0.916863  [    0/60000]
# loss: 0.803380  [ 6400/60000]
# loss: 0.881366  [12800/60000]
# loss: 0.799700  [19200/60000]
# loss: 0.803414  [25600/60000]
# loss: 0.763624  [32000/60000]
# loss: 0.736022  [38400/60000]
# loss: 0.862678  [44800/60000]
# loss: 0.779951  [51200/60000]
# loss: 0.761910  [57600/60000]
# Test Error:
#  Accuracy: 81.5%, Precision: 81.7%, Recall: 81.0%, F1: 79.6%, Avg loss: 0.745157
#
# Epoch 11
# -------------------------------
# loss: 0.824431  [    0/60000]
# loss: 0.711655  [ 6400/60000]
# loss: 0.772455  [12800/60000]
# loss: 0.718753  [19200/60000]
# loss: 0.710864  [25600/60000]
# loss: 0.674933  [32000/60000]
# loss: 0.647450  [38400/60000]
# loss: 0.773413  [44800/60000]
# loss: 0.706720  [51200/60000]
# loss: 0.693234  [57600/60000]
# Test Error:
#  Accuracy: 83.0%, Precision: 83.0%, Recall: 82.4%, F1: 81.2%, Avg loss: 0.669676
#
# Epoch 12
# -------------------------------
# loss: 0.751714  [    0/60000]
# loss: 0.639994  [ 6400/60000]
# loss: 0.688860  [12800/60000]
# loss: 0.658139  [19200/60000]
# loss: 0.638093  [25600/60000]
# loss: 0.609228  [32000/60000]
# loss: 0.575779  [38400/60000]
# loss: 0.706492  [44800/60000]
# loss: 0.649683  [51200/60000]
# loss: 0.641713  [57600/60000]
# Test Error:
#  Accuracy: 84.3%, Precision: 84.1%, Recall: 83.8%, F1: 82.5%, Avg loss: 0.611176
#
# Epoch 13
# -------------------------------
# loss: 0.693022  [    0/60000]
# loss: 0.581632  [ 6400/60000]
# loss: 0.623463  [12800/60000]
# loss: 0.611641  [19200/60000]
# loss: 0.579925  [25600/60000]
# loss: 0.559940  [32000/60000]
# loss: 0.517525  [38400/60000]
# loss: 0.655778  [44800/60000]
# loss: 0.603795  [51200/60000]
# loss: 0.602672  [57600/60000]
# Test Error:
#  Accuracy: 85.4%, Precision: 85.2%, Recall: 84.8%, F1: 83.7%, Avg loss: 0.564881
#
# Epoch 14
# -------------------------------
# loss: 0.644631  [    0/60000]
# loss: 0.533200  [ 6400/60000]
# loss: 0.571275  [12800/60000]
# loss: 0.575210  [19200/60000]
# loss: 0.532750  [25600/60000]
# loss: 0.522540  [32000/60000]
# loss: 0.469909  [38400/60000]
# loss: 0.616732  [44800/60000]
# loss: 0.566524  [51200/60000]
# loss: 0.572640  [57600/60000]
# Test Error:
#  Accuracy: 86.2%, Precision: 86.2%, Recall: 85.9%, F1: 84.7%, Avg loss: 0.527637
#
# Epoch 15
# -------------------------------
# loss: 0.603903  [    0/60000]
# loss: 0.492804  [ 6400/60000]
# loss: 0.529105  [12800/60000]
# loss: 0.546183  [19200/60000]
# loss: 0.494280  [25600/60000]
# loss: 0.493828  [32000/60000]
# loss: 0.430971  [38400/60000]
# loss: 0.586093  [44800/60000]
# loss: 0.536109  [51200/60000]
# loss: 0.549330  [57600/60000]
# Test Error:
#  Accuracy: 86.9%, Precision: 86.8%, Recall: 86.6%, F1: 85.5%, Avg loss: 0.497281
#
# Epoch 16
# -------------------------------
# loss: 0.569065  [    0/60000]
# loss: 0.459259  [ 6400/60000]
# loss: 0.494419  [12800/60000]
# loss: 0.522532  [19200/60000]
# loss: 0.462700  [25600/60000]
# loss: 0.471514  [32000/60000]
# loss: 0.399258  [38400/60000]
# loss: 0.561401  [44800/60000]
# loss: 0.511193  [51200/60000]
# loss: 0.530958  [57600/60000]
# Test Error:
#  Accuracy: 87.6%, Precision: 87.6%, Recall: 87.3%, F1: 86.3%, Avg loss: 0.472258
#
# Epoch 17
# -------------------------------
# loss: 0.538931  [    0/60000]
# loss: 0.431364  [ 6400/60000]
# loss: 0.465447  [12800/60000]
# loss: 0.502918  [19200/60000]
# loss: 0.436659  [25600/60000]
# loss: 0.453920  [32000/60000]
# loss: 0.373274  [38400/60000]
# loss: 0.541104  [44800/60000]
# loss: 0.490687  [51200/60000]
# loss: 0.516215  [57600/60000]
# Test Error:
#  Accuracy: 88.2%, Precision: 88.1%, Recall: 87.8%, F1: 86.9%, Avg loss: 0.451404
#
# Epoch 18
# -------------------------------
# loss: 0.512453  [    0/60000]
# loss: 0.408026  [ 6400/60000]
# loss: 0.441020  [12800/60000]
# loss: 0.486487  [19200/60000]
# loss: 0.414985  [25600/60000]
# loss: 0.439866  [32000/60000]
# loss: 0.351686  [38400/60000]
# loss: 0.524177  [44800/60000]
# loss: 0.473777  [51200/60000]
# loss: 0.504173  [57600/60000]
# Test Error:
#  Accuracy: 88.4%, Precision: 88.4%, Recall: 88.2%, F1: 87.2%, Avg loss: 0.433835
#
# Epoch 19
# -------------------------------
# loss: 0.489037  [    0/60000]
# loss: 0.388405  [ 6400/60000]
# loss: 0.420049  [12800/60000]
# loss: 0.472528  [19200/60000]
# loss: 0.396772  [25600/60000]
# loss: 0.428379  [32000/60000]
# loss: 0.333601  [38400/60000]
# loss: 0.509746  [44800/60000]
# loss: 0.459657  [51200/60000]
# loss: 0.494291  [57600/60000]
# Test Error:
#  Accuracy: 88.7%, Precision: 88.7%, Recall: 88.4%, F1: 87.5%, Avg loss: 0.418899
#
# Epoch 20
# -------------------------------
# loss: 0.468230  [    0/60000]
# loss: 0.371856  [ 6400/60000]
# loss: 0.401852  [12800/60000]
# loss: 0.460444  [19200/60000]
# loss: 0.381218  [25600/60000]
# loss: 0.418877  [32000/60000]
# loss: 0.318305  [38400/60000]
# loss: 0.497285  [44800/60000]
# loss: 0.447756  [51200/60000]
# loss: 0.486010  [57600/60000]
# Test Error:
#  Accuracy: 89.1%, Precision: 89.1%, Recall: 88.8%, F1: 87.9%, Avg loss: 0.406074
#
# Epoch 21
# -------------------------------
# loss: 0.449623  [    0/60000]
# loss: 0.357779  [ 6400/60000]
# loss: 0.385856  [12800/60000]
# loss: 0.449916  [19200/60000]
# loss: 0.367803  [25600/60000]
# loss: 0.410836  [32000/60000]
# loss: 0.305228  [38400/60000]
# loss: 0.486448  [44800/60000]
# loss: 0.437453  [51200/60000]
# loss: 0.479071  [57600/60000]
# Test Error:
#  Accuracy: 89.2%, Precision: 89.3%, Recall: 89.0%, F1: 88.1%, Avg loss: 0.394958
#
# Epoch 22
# -------------------------------
# loss: 0.432781  [    0/60000]
# loss: 0.345734  [ 6400/60000]
# loss: 0.371649  [12800/60000]
# loss: 0.440671  [19200/60000]
# loss: 0.356176  [25600/60000]
# loss: 0.403870  [32000/60000]
# loss: 0.293927  [38400/60000]
# loss: 0.476858  [44800/60000]
# loss: 0.428462  [51200/60000]
# loss: 0.473206  [57600/60000]
# Test Error:
#  Accuracy: 89.4%, Precision: 89.4%, Recall: 89.2%, F1: 88.3%, Avg loss: 0.385249
#
# Epoch 23
# -------------------------------
# loss: 0.417517  [    0/60000]
# loss: 0.335372  [ 6400/60000]
# loss: 0.358837  [12800/60000]
# loss: 0.432458  [19200/60000]
# loss: 0.345963  [25600/60000]
# loss: 0.397691  [32000/60000]
# loss: 0.284037  [38400/60000]
# loss: 0.468326  [44800/60000]
# loss: 0.420433  [51200/60000]
# loss: 0.468164  [57600/60000]
# Test Error:
#  Accuracy: 89.6%, Precision: 89.7%, Recall: 89.4%, F1: 88.4%, Avg loss: 0.376699
#
# Epoch 24
# -------------------------------
# loss: 0.403596  [    0/60000]
# loss: 0.326443  [ 6400/60000]
# loss: 0.347230  [12800/60000]
# loss: 0.425130  [19200/60000]
# loss: 0.336863  [25600/60000]
# loss: 0.392134  [32000/60000]
# loss: 0.275306  [38400/60000]
# loss: 0.460714  [44800/60000]
# loss: 0.413233  [51200/60000]
# loss: 0.463854  [57600/60000]
# Test Error:
#  Accuracy: 89.7%, Precision: 89.8%, Recall: 89.5%, F1: 88.6%, Avg loss: 0.369104
#
# Epoch 25
# -------------------------------
# loss: 0.390882  [    0/60000]
# loss: 0.318679  [ 6400/60000]
# loss: 0.336607  [12800/60000]
# loss: 0.418552  [19200/60000]
# loss: 0.328723  [25600/60000]
# loss: 0.387080  [32000/60000]
# loss: 0.267574  [38400/60000]
# loss: 0.453832  [44800/60000]
# loss: 0.406688  [51200/60000]
# loss: 0.460069  [57600/60000]
# Test Error:
#  Accuracy: 89.9%, Precision: 90.0%, Recall: 89.7%, F1: 88.8%, Avg loss: 0.362311
#
# Epoch 26
# -------------------------------
# loss: 0.379199  [    0/60000]
# loss: 0.311905  [ 6400/60000]
# loss: 0.326858  [12800/60000]
# loss: 0.412605  [19200/60000]
# loss: 0.321351  [25600/60000]
# loss: 0.382450  [32000/60000]
# loss: 0.260717  [38400/60000]
# loss: 0.447631  [44800/60000]
# loss: 0.400694  [51200/60000]
# loss: 0.456634  [57600/60000]
# Test Error:
#  Accuracy: 90.0%, Precision: 90.1%, Recall: 89.8%, F1: 88.9%, Avg loss: 0.356185
#
# Epoch 27
# -------------------------------
# loss: 0.368427  [    0/60000]
# loss: 0.305947  [ 6400/60000]
# loss: 0.317862  [12800/60000]
# loss: 0.407176  [19200/60000]
# loss: 0.314679  [25600/60000]
# loss: 0.378193  [32000/60000]
# loss: 0.254651  [38400/60000]
# loss: 0.441964  [44800/60000]
# loss: 0.395087  [51200/60000]
# loss: 0.453490  [57600/60000]
# Test Error:
#  Accuracy: 90.2%, Precision: 90.2%, Recall: 89.9%, F1: 89.1%, Avg loss: 0.350629
#
# Epoch 28
# -------------------------------
# loss: 0.358520  [    0/60000]
# loss: 0.300613  [ 6400/60000]
# loss: 0.309559  [12800/60000]
# loss: 0.402181  [19200/60000]
# loss: 0.308556  [25600/60000]
# loss: 0.374303  [32000/60000]
# loss: 0.249288  [38400/60000]
# loss: 0.436644  [44800/60000]
# loss: 0.389870  [51200/60000]
# loss: 0.450568  [57600/60000]
# Test Error:
#  Accuracy: 90.3%, Precision: 90.3%, Recall: 90.0%, F1: 89.2%, Avg loss: 0.345551
#
# Epoch 29
# -------------------------------
# loss: 0.349373  [    0/60000]
# loss: 0.295930  [ 6400/60000]
# loss: 0.301807  [12800/60000]
# loss: 0.397525  [19200/60000]
# loss: 0.302902  [25600/60000]
# loss: 0.370648  [32000/60000]
# loss: 0.244486  [38400/60000]
# loss: 0.431704  [44800/60000]
# loss: 0.384982  [51200/60000]
# loss: 0.447808  [57600/60000]
# Test Error:
#  Accuracy: 90.3%, Precision: 90.4%, Recall: 90.1%, F1: 89.2%, Avg loss: 0.340881
#
# Epoch 30
# -------------------------------
# loss: 0.340871  [    0/60000]
# loss: 0.291811  [ 6400/60000]
# loss: 0.294567  [12800/60000]
# loss: 0.393190  [19200/60000]
# loss: 0.297671  [25600/60000]
# loss: 0.367247  [32000/60000]
# loss: 0.240211  [38400/60000]
# loss: 0.427107  [44800/60000]
# loss: 0.380404  [51200/60000]
# loss: 0.445137  [57600/60000]
# Test Error:
#  Accuracy: 90.4%, Precision: 90.5%, Recall: 90.2%, F1: 89.3%, Avg loss: 0.336557
#
# Epoch 31
# -------------------------------
# loss: 0.332961  [    0/60000]
# loss: 0.287995  [ 6400/60000]
# loss: 0.287783  [12800/60000]
# loss: 0.389109  [19200/60000]
# loss: 0.292773  [25600/60000]
# loss: 0.364010  [32000/60000]
# loss: 0.236304  [38400/60000]
# loss: 0.422856  [44800/60000]
# loss: 0.376082  [51200/60000]
# loss: 0.442576  [57600/60000]
# Test Error:
#  Accuracy: 90.5%, Precision: 90.7%, Recall: 90.3%, F1: 89.5%, Avg loss: 0.332535
#
# Epoch 32
# -------------------------------
# loss: 0.325601  [    0/60000]
# loss: 0.284478  [ 6400/60000]
# loss: 0.281406  [12800/60000]
# loss: 0.385268  [19200/60000]
# loss: 0.288231  [25600/60000]
# loss: 0.360949  [32000/60000]
# loss: 0.232748  [38400/60000]
# loss: 0.418893  [44800/60000]
# loss: 0.371980  [51200/60000]
# loss: 0.440068  [57600/60000]
# Test Error:
#  Accuracy: 90.6%, Precision: 90.6%, Recall: 90.3%, F1: 89.5%, Avg loss: 0.328776
#
# Epoch 33
# -------------------------------
# loss: 0.318625  [    0/60000]
# loss: 0.281324  [ 6400/60000]
# loss: 0.275404  [12800/60000]
# loss: 0.381682  [19200/60000]
# loss: 0.283988  [25600/60000]
# loss: 0.358096  [32000/60000]
# loss: 0.229552  [38400/60000]
# loss: 0.415181  [44800/60000]
# loss: 0.368045  [51200/60000]
# loss: 0.437444  [57600/60000]
# Test Error:
#  Accuracy: 90.6%, Precision: 90.7%, Recall: 90.3%, F1: 89.5%, Avg loss: 0.325253
#
# Epoch 34
# -------------------------------
# loss: 0.312066  [    0/60000]
# loss: 0.278410  [ 6400/60000]
# loss: 0.269690  [12800/60000]
# loss: 0.378261  [19200/60000]
# loss: 0.279962  [25600/60000]
# loss: 0.355385  [32000/60000]
# loss: 0.226679  [38400/60000]
# loss: 0.411708  [44800/60000]
# loss: 0.364300  [51200/60000]
# loss: 0.434766  [57600/60000]
# Test Error:
#  Accuracy: 90.7%, Precision: 90.8%, Recall: 90.5%, F1: 89.7%, Avg loss: 0.321928
#
# Epoch 35
# -------------------------------
# loss: 0.305881  [    0/60000]
# loss: 0.275712  [ 6400/60000]
# loss: 0.264384  [12800/60000]
# loss: 0.375004  [19200/60000]
# loss: 0.276194  [25600/60000]
# loss: 0.352722  [32000/60000]
# loss: 0.224073  [38400/60000]
# loss: 0.408443  [44800/60000]
# loss: 0.360762  [51200/60000]
# loss: 0.432144  [57600/60000]
# Test Error:
#  Accuracy: 90.8%, Precision: 90.9%, Recall: 90.6%, F1: 89.8%, Avg loss: 0.318783
#
# Epoch 36
# -------------------------------
# loss: 0.300001  [    0/60000]
# loss: 0.273208  [ 6400/60000]
# loss: 0.259520  [12800/60000]
# loss: 0.371885  [19200/60000]
# loss: 0.272667  [25600/60000]
# loss: 0.350108  [32000/60000]
# loss: 0.221688  [38400/60000]
# loss: 0.405374  [44800/60000]
# loss: 0.357312  [51200/60000]
# loss: 0.429468  [57600/60000]
# Test Error:
#  Accuracy: 90.9%, Precision: 91.0%, Recall: 90.6%, F1: 89.8%, Avg loss: 0.315798
#
# Epoch 37
# -------------------------------
# loss: 0.294439  [    0/60000]
# loss: 0.270909  [ 6400/60000]
# loss: 0.254912  [12800/60000]
# loss: 0.368882  [19200/60000]
# loss: 0.269300  [25600/60000]
# loss: 0.347633  [32000/60000]
# loss: 0.219466  [38400/60000]
# loss: 0.402522  [44800/60000]
# loss: 0.353916  [51200/60000]
# loss: 0.426804  [57600/60000]
# Test Error:
#  Accuracy: 91.0%, Precision: 91.1%, Recall: 90.7%, F1: 89.9%, Avg loss: 0.312962
#
# Epoch 38
# -------------------------------
# loss: 0.289146  [    0/60000]
# loss: 0.268832  [ 6400/60000]
# loss: 0.250508  [12800/60000]
# loss: 0.365950  [19200/60000]
# loss: 0.265908  [25600/60000]
# loss: 0.345303  [32000/60000]
# loss: 0.217356  [38400/60000]
# loss: 0.399821  [44800/60000]
# loss: 0.350600  [51200/60000]
# loss: 0.424149  [57600/60000]
# Test Error:
#  Accuracy: 91.0%, Precision: 91.2%, Recall: 90.8%, F1: 90.0%, Avg loss: 0.310252
#
# Epoch 39
# -------------------------------
# loss: 0.284098  [    0/60000]
# loss: 0.266839  [ 6400/60000]
# loss: 0.246312  [12800/60000]
# loss: 0.363090  [19200/60000]
# loss: 0.262530  [25600/60000]
# loss: 0.343054  [32000/60000]
# loss: 0.215436  [38400/60000]
# loss: 0.397266  [44800/60000]
# loss: 0.347355  [51200/60000]
# loss: 0.421445  [57600/60000]
# Test Error:
#  Accuracy: 91.1%, Precision: 91.2%, Recall: 90.8%, F1: 90.1%, Avg loss: 0.307660
#
# Epoch 40
# -------------------------------
# loss: 0.279320  [    0/60000]
# loss: 0.264977  [ 6400/60000]
# loss: 0.242339  [12800/60000]
# loss: 0.360332  [19200/60000]
# loss: 0.259316  [25600/60000]
# loss: 0.340873  [32000/60000]
# loss: 0.213638  [38400/60000]
# loss: 0.394919  [44800/60000]
# loss: 0.344200  [51200/60000]
# loss: 0.418850  [57600/60000]
# Test Error:
#  Accuracy: 91.2%, Precision: 91.3%, Recall: 90.9%, F1: 90.2%, Avg loss: 0.305180
#
# Epoch 41
# -------------------------------
# loss: 0.274789  [    0/60000]
# loss: 0.263198  [ 6400/60000]
# loss: 0.238688  [12800/60000]
# loss: 0.357639  [19200/60000]
# loss: 0.256323  [25600/60000]
# loss: 0.338768  [32000/60000]
# loss: 0.211930  [38400/60000]
# loss: 0.392702  [44800/60000]
# loss: 0.341242  [51200/60000]
# loss: 0.416211  [57600/60000]
# Test Error:
#  Accuracy: 91.2%, Precision: 91.3%, Recall: 91.0%, F1: 90.2%, Avg loss: 0.302797
#
# Epoch 42
# -------------------------------
# loss: 0.270406  [    0/60000]
# loss: 0.261490  [ 6400/60000]
# loss: 0.235218  [12800/60000]
# loss: 0.354984  [19200/60000]
# loss: 0.253450  [25600/60000]
# loss: 0.336694  [32000/60000]
# loss: 0.210338  [38400/60000]
# loss: 0.390675  [44800/60000]
# loss: 0.338324  [51200/60000]
# loss: 0.413629  [57600/60000]
# Test Error:
#  Accuracy: 91.2%, Precision: 91.3%, Recall: 91.0%, F1: 90.2%, Avg loss: 0.300498
#
# Epoch 43
# -------------------------------
# loss: 0.266230  [    0/60000]
# loss: 0.259919  [ 6400/60000]
# loss: 0.231920  [12800/60000]
# loss: 0.352367  [19200/60000]
# loss: 0.250628  [25600/60000]
# loss: 0.334689  [32000/60000]
# loss: 0.208804  [38400/60000]
# loss: 0.388788  [44800/60000]
# loss: 0.335492  [51200/60000]
# loss: 0.411007  [57600/60000]
# Test Error:
#  Accuracy: 91.4%, Precision: 91.4%, Recall: 91.1%, F1: 90.4%, Avg loss: 0.298277
#
# Epoch 44
# -------------------------------
# loss: 0.262207  [    0/60000]
# loss: 0.258498  [ 6400/60000]
# loss: 0.228685  [12800/60000]
# loss: 0.349798  [19200/60000]
# loss: 0.247895  [25600/60000]
# loss: 0.332722  [32000/60000]
# loss: 0.207351  [38400/60000]
# loss: 0.387040  [44800/60000]
# loss: 0.332704  [51200/60000]
# loss: 0.408322  [57600/60000]
# Test Error:
#  Accuracy: 91.5%, Precision: 91.5%, Recall: 91.2%, F1: 90.5%, Avg loss: 0.296122
#
# Epoch 45
# -------------------------------
# loss: 0.258353  [    0/60000]
# loss: 0.257195  [ 6400/60000]
# loss: 0.225585  [12800/60000]
# loss: 0.347255  [19200/60000]
# loss: 0.245273  [25600/60000]
# loss: 0.330820  [32000/60000]
# loss: 0.205979  [38400/60000]
# loss: 0.385356  [44800/60000]
# loss: 0.329948  [51200/60000]
# loss: 0.405463  [57600/60000]
# Test Error:
#  Accuracy: 91.5%, Precision: 91.6%, Recall: 91.2%, F1: 90.5%, Avg loss: 0.294039
#
# Epoch 46
# -------------------------------
# loss: 0.254643  [    0/60000]
# loss: 0.255927  [ 6400/60000]
# loss: 0.222572  [12800/60000]
# loss: 0.344781  [19200/60000]
# loss: 0.242747  [25600/60000]
# loss: 0.328983  [32000/60000]
# loss: 0.204629  [38400/60000]
# loss: 0.383730  [44800/60000]
# loss: 0.327251  [51200/60000]
# loss: 0.402491  [57600/60000]
# Test Error:
#  Accuracy: 91.6%, Precision: 91.7%, Recall: 91.3%, F1: 90.7%, Avg loss: 0.292012
#
# Epoch 47
# -------------------------------
# loss: 0.251078  [    0/60000]
# loss: 0.254604  [ 6400/60000]
# loss: 0.219676  [12800/60000]
# loss: 0.342495  [19200/60000]
# loss: 0.240329  [25600/60000]
# loss: 0.327164  [32000/60000]
# loss: 0.203271  [38400/60000]
# loss: 0.382134  [44800/60000]
# loss: 0.324662  [51200/60000]
# loss: 0.399577  [57600/60000]
# Test Error:
#  Accuracy: 91.7%, Precision: 91.8%, Recall: 91.4%, F1: 90.8%, Avg loss: 0.290033
#
# Epoch 48
# -------------------------------
# loss: 0.247654  [    0/60000]
# loss: 0.253268  [ 6400/60000]
# loss: 0.216852  [12800/60000]
# loss: 0.340214  [19200/60000]
# loss: 0.237993  [25600/60000]
# loss: 0.325367  [32000/60000]
# loss: 0.201980  [38400/60000]
# loss: 0.380562  [44800/60000]
# loss: 0.322122  [51200/60000]
# loss: 0.396663  [57600/60000]
# Test Error:
#  Accuracy: 91.8%, Precision: 91.8%, Recall: 91.5%, F1: 90.8%, Avg loss: 0.288109
#
# Epoch 49
# -------------------------------
# loss: 0.244365  [    0/60000]
# loss: 0.252024  [ 6400/60000]
# loss: 0.214120  [12800/60000]
# loss: 0.338003  [19200/60000]
# loss: 0.235713  [25600/60000]
# loss: 0.323640  [32000/60000]
# loss: 0.200733  [38400/60000]
# loss: 0.379136  [44800/60000]
# loss: 0.319602  [51200/60000]
# loss: 0.393820  [57600/60000]
# Test Error:
#  Accuracy: 91.8%, Precision: 91.9%, Recall: 91.6%, F1: 90.9%, Avg loss: 0.286227
#
# Epoch 50
# -------------------------------
# loss: 0.241208  [    0/60000]
# loss: 0.250819  [ 6400/60000]
# loss: 0.211483  [12800/60000]
# loss: 0.335769  [19200/60000]
# loss: 0.233464  [25600/60000]
# loss: 0.321921  [32000/60000]
# loss: 0.199527  [38400/60000]
# loss: 0.377702  [44800/60000]
# loss: 0.317099  [51200/60000]
# loss: 0.390957  [57600/60000]
# Test Error:
#  Accuracy: 91.9%, Precision: 92.0%, Recall: 91.6%, F1: 90.9%, Avg loss: 0.284387
#
# Epoch 51
# -------------------------------
# loss: 0.238123  [    0/60000]
# loss: 0.249601  [ 6400/60000]
# loss: 0.208904  [12800/60000]
# loss: 0.333814  [19200/60000]
# loss: 0.231307  [25600/60000]
# loss: 0.320211  [32000/60000]
# loss: 0.198334  [38400/60000]
# loss: 0.376050  [44800/60000]
# loss: 0.314657  [51200/60000]
# loss: 0.388261  [57600/60000]
# Test Error:
#  Accuracy: 91.9%, Precision: 92.0%, Recall: 91.6%, F1: 90.9%, Avg loss: 0.282584
#
# Epoch 52
# -------------------------------
# loss: 0.235064  [    0/60000]
# loss: 0.248234  [ 6400/60000]
# loss: 0.206417  [12800/60000]
# loss: 0.332273  [19200/60000]
# loss: 0.229272  [25600/60000]
# loss: 0.318486  [32000/60000]
# loss: 0.197189  [38400/60000]
# loss: 0.374253  [44800/60000]
# loss: 0.312256  [51200/60000]
# loss: 0.385570  [57600/60000]
# Test Error:
#  Accuracy: 91.9%, Precision: 92.0%, Recall: 91.6%, F1: 91.0%, Avg loss: 0.280805
#
# Epoch 53
# -------------------------------
# loss: 0.232119  [    0/60000]
# loss: 0.246900  [ 6400/60000]
# loss: 0.204020  [12800/60000]
# loss: 0.330823  [19200/60000]
# loss: 0.227202  [25600/60000]
# loss: 0.316799  [32000/60000]
# loss: 0.196031  [38400/60000]
# loss: 0.372590  [44800/60000]
# loss: 0.309812  [51200/60000]
# loss: 0.382937  [57600/60000]
# Test Error:
#  Accuracy: 92.0%, Precision: 92.0%, Recall: 91.7%, F1: 91.0%, Avg loss: 0.279052
#
# Epoch 54
# -------------------------------
# loss: 0.229266  [    0/60000]
# loss: 0.245563  [ 6400/60000]
# loss: 0.201647  [12800/60000]
# loss: 0.329355  [19200/60000]
# loss: 0.225165  [25600/60000]
# loss: 0.314780  [32000/60000]
# loss: 0.194860  [38400/60000]
# loss: 0.371017  [44800/60000]
# loss: 0.306803  [51200/60000]
# loss: 0.380299  [57600/60000]
# Test Error:
#  Accuracy: 92.1%, Precision: 92.1%, Recall: 91.8%, F1: 91.1%, Avg loss: 0.277328
#
# Epoch 55
# -------------------------------
# loss: 0.226482  [    0/60000]
# loss: 0.244277  [ 6400/60000]
# loss: 0.199342  [12800/60000]
# loss: 0.327845  [19200/60000]
# loss: 0.223217  [25600/60000]
# loss: 0.312953  [32000/60000]
# loss: 0.193723  [38400/60000]
# loss: 0.369496  [44800/60000]
# loss: 0.303749  [51200/60000]
# loss: 0.377749  [57600/60000]
# Test Error:
#  Accuracy: 92.2%, Precision: 92.2%, Recall: 91.9%, F1: 91.3%, Avg loss: 0.275638
#
# Epoch 56
# -------------------------------
# loss: 0.223711  [    0/60000]
# loss: 0.243033  [ 6400/60000]
# loss: 0.197090  [12800/60000]
# loss: 0.326279  [19200/60000]
# loss: 0.221320  [25600/60000]
# loss: 0.311273  [32000/60000]
# loss: 0.192630  [38400/60000]
# loss: 0.368100  [44800/60000]
# loss: 0.300724  [51200/60000]
# loss: 0.375110  [57600/60000]
# Test Error:
#  Accuracy: 92.3%, Precision: 92.3%, Recall: 92.0%, F1: 91.3%, Avg loss: 0.273994
#
# Epoch 57
# -------------------------------
# loss: 0.221009  [    0/60000]
# loss: 0.241881  [ 6400/60000]
# loss: 0.194932  [12800/60000]
# loss: 0.324614  [19200/60000]
# loss: 0.219526  [25600/60000]
# loss: 0.309659  [32000/60000]
# loss: 0.191562  [38400/60000]
# loss: 0.366727  [44800/60000]
# loss: 0.297762  [51200/60000]
# loss: 0.372511  [57600/60000]
# Test Error:
#  Accuracy: 92.3%, Precision: 92.3%, Recall: 92.0%, F1: 91.4%, Avg loss: 0.272377
#
# Epoch 58
# -------------------------------
# loss: 0.218387  [    0/60000]
# loss: 0.240759  [ 6400/60000]
# loss: 0.192824  [12800/60000]
# loss: 0.322947  [19200/60000]
# loss: 0.217779  [25600/60000]
# loss: 0.308036  [32000/60000]
# loss: 0.190454  [38400/60000]
# loss: 0.365357  [44800/60000]
# loss: 0.294835  [51200/60000]
# loss: 0.369968  [57600/60000]
# Test Error:
#  Accuracy: 92.3%, Precision: 92.3%, Recall: 92.0%, F1: 91.4%, Avg loss: 0.270786
#
# Epoch 59
# -------------------------------
# loss: 0.215768  [    0/60000]
# loss: 0.239677  [ 6400/60000]
# loss: 0.190779  [12800/60000]
# loss: 0.321369  [19200/60000]
# loss: 0.216280  [25600/60000]
# loss: 0.306458  [32000/60000]
# loss: 0.189390  [38400/60000]
# loss: 0.363936  [44800/60000]
# loss: 0.291932  [51200/60000]
# loss: 0.367487  [57600/60000]
# Test Error:
#  Accuracy: 92.4%, Precision: 92.4%, Recall: 92.1%, F1: 91.5%, Avg loss: 0.269228
#
# Epoch 60
# -------------------------------
# loss: 0.213207  [    0/60000]
# loss: 0.238597  [ 6400/60000]
# loss: 0.188729  [12800/60000]
# loss: 0.319803  [19200/60000]
# loss: 0.214825  [25600/60000]
# loss: 0.304897  [32000/60000]
# loss: 0.188306  [38400/60000]
# loss: 0.362572  [44800/60000]
# loss: 0.289098  [51200/60000]
# loss: 0.365084  [57600/60000]
# Test Error:
#  Accuracy: 92.4%, Precision: 92.4%, Recall: 92.1%, F1: 91.5%, Avg loss: 0.267699
#
# Epoch 61
# -------------------------------
# loss: 0.210659  [    0/60000]
# loss: 0.237509  [ 6400/60000]
# loss: 0.186721  [12800/60000]
# loss: 0.318150  [19200/60000]
# loss: 0.213451  [25600/60000]
# loss: 0.303210  [32000/60000]
# loss: 0.187283  [38400/60000]
# loss: 0.361272  [44800/60000]
# loss: 0.286288  [51200/60000]
# loss: 0.362681  [57600/60000]
# Test Error:
#  Accuracy: 92.5%, Precision: 92.5%, Recall: 92.2%, F1: 91.6%, Avg loss: 0.266183
#
# Epoch 62
# -------------------------------
# loss: 0.208174  [    0/60000]
# loss: 0.236406  [ 6400/60000]
# loss: 0.184699  [12800/60000]
# loss: 0.316482  [19200/60000]
# loss: 0.212062  [25600/60000]
# loss: 0.301675  [32000/60000]
# loss: 0.186258  [38400/60000]
# loss: 0.359942  [44800/60000]
# loss: 0.283477  [51200/60000]
# loss: 0.360386  [57600/60000]
# Test Error:
#  Accuracy: 92.6%, Precision: 92.5%, Recall: 92.3%, F1: 91.6%, Avg loss: 0.264688
#
# Epoch 63
# -------------------------------
# loss: 0.205698  [    0/60000]
# loss: 0.235413  [ 6400/60000]
# loss: 0.182719  [12800/60000]
# loss: 0.314822  [19200/60000]
# loss: 0.210704  [25600/60000]
# loss: 0.300082  [32000/60000]
# loss: 0.185259  [38400/60000]
# loss: 0.358582  [44800/60000]
# loss: 0.280831  [51200/60000]
# loss: 0.358103  [57600/60000]
# Test Error:
#  Accuracy: 92.6%, Precision: 92.6%, Recall: 92.3%, F1: 91.7%, Avg loss: 0.263209
#
# Epoch 64
# -------------------------------
# loss: 0.203341  [    0/60000]
# loss: 0.234318  [ 6400/60000]
# loss: 0.180831  [12800/60000]
# loss: 0.313279  [19200/60000]
# loss: 0.209438  [25600/60000]
# loss: 0.298465  [32000/60000]
# loss: 0.184252  [38400/60000]
# loss: 0.357282  [44800/60000]
# loss: 0.278190  [51200/60000]
# loss: 0.355831  [57600/60000]
# Test Error:
#  Accuracy: 92.6%, Precision: 92.6%, Recall: 92.3%, F1: 91.7%, Avg loss: 0.261747
#
# Epoch 65
# -------------------------------
# loss: 0.201056  [    0/60000]
# loss: 0.233229  [ 6400/60000]
# loss: 0.179004  [12800/60000]
# loss: 0.311748  [19200/60000]
# loss: 0.208148  [25600/60000]
# loss: 0.296920  [32000/60000]
# loss: 0.183254  [38400/60000]
# loss: 0.355986  [44800/60000]
# loss: 0.275455  [51200/60000]
# loss: 0.353602  [57600/60000]
# Test Error:
#  Accuracy: 92.7%, Precision: 92.7%, Recall: 92.4%, F1: 91.8%, Avg loss: 0.260292
#
# Epoch 66
# -------------------------------
# loss: 0.198773  [    0/60000]
# loss: 0.232124  [ 6400/60000]
# loss: 0.177234  [12800/60000]
# loss: 0.310183  [19200/60000]
# loss: 0.206822  [25600/60000]
# loss: 0.295495  [32000/60000]
# loss: 0.182258  [38400/60000]
# loss: 0.354673  [44800/60000]
# loss: 0.272746  [51200/60000]
# loss: 0.351474  [57600/60000]
# Test Error:
#  Accuracy: 92.7%, Precision: 92.7%, Recall: 92.4%, F1: 91.8%, Avg loss: 0.258851
#
# Epoch 67
# -------------------------------
# loss: 0.196508  [    0/60000]
# loss: 0.230974  [ 6400/60000]
# loss: 0.175526  [12800/60000]
# loss: 0.308604  [19200/60000]
# loss: 0.205550  [25600/60000]
# loss: 0.294111  [32000/60000]
# loss: 0.181301  [38400/60000]
# loss: 0.353379  [44800/60000]
# loss: 0.270131  [51200/60000]
# loss: 0.349379  [57600/60000]
# Test Error:
#  Accuracy: 92.7%, Precision: 92.7%, Recall: 92.4%, F1: 91.8%, Avg loss: 0.257422
#
# Epoch 68
# -------------------------------
# loss: 0.194321  [    0/60000]
# loss: 0.229783  [ 6400/60000]
# loss: 0.173896  [12800/60000]
# loss: 0.307040  [19200/60000]
# loss: 0.204266  [25600/60000]
# loss: 0.292713  [32000/60000]
# loss: 0.180305  [38400/60000]
# loss: 0.352118  [44800/60000]
# loss: 0.267593  [51200/60000]
# loss: 0.347281  [57600/60000]
# Test Error:
#  Accuracy: 92.8%, Precision: 92.7%, Recall: 92.5%, F1: 91.8%, Avg loss: 0.256016
#
# Epoch 69
# -------------------------------
# loss: 0.192155  [    0/60000]
# loss: 0.228615  [ 6400/60000]
# loss: 0.172224  [12800/60000]
# loss: 0.305486  [19200/60000]
# loss: 0.202976  [25600/60000]
# loss: 0.291343  [32000/60000]
# loss: 0.179307  [38400/60000]
# loss: 0.350880  [44800/60000]
# loss: 0.265098  [51200/60000]
# loss: 0.345132  [57600/60000]
# Test Error:
#  Accuracy: 92.8%, Precision: 92.8%, Recall: 92.5%, F1: 91.9%, Avg loss: 0.254616
#
# Epoch 70
# -------------------------------
# loss: 0.190043  [    0/60000]
# loss: 0.227468  [ 6400/60000]
# loss: 0.170573  [12800/60000]
# loss: 0.303909  [19200/60000]
# loss: 0.201687  [25600/60000]
# loss: 0.290001  [32000/60000]
# loss: 0.178300  [38400/60000]
# loss: 0.349613  [44800/60000]
# loss: 0.262714  [51200/60000]
# loss: 0.343092  [57600/60000]
# Test Error:
#  Accuracy: 92.9%, Precision: 92.8%, Recall: 92.6%, F1: 91.9%, Avg loss: 0.253230
#
# Epoch 71
# -------------------------------
# loss: 0.187980  [    0/60000]
# loss: 0.226363  [ 6400/60000]
# loss: 0.168986  [12800/60000]
# loss: 0.302333  [19200/60000]
# loss: 0.200387  [25600/60000]
# loss: 0.288654  [32000/60000]
# loss: 0.177302  [38400/60000]
# loss: 0.348358  [44800/60000]
# loss: 0.260442  [51200/60000]
# loss: 0.341097  [57600/60000]
# Test Error:
#  Accuracy: 93.0%, Precision: 92.9%, Recall: 92.7%, F1: 92.1%, Avg loss: 0.251852
#
# Epoch 72
# -------------------------------
# loss: 0.185978  [    0/60000]
# loss: 0.225272  [ 6400/60000]
# loss: 0.167429  [12800/60000]
# loss: 0.300729  [19200/60000]
# loss: 0.199069  [25600/60000]
# loss: 0.287412  [32000/60000]
# loss: 0.176285  [38400/60000]
# loss: 0.347099  [44800/60000]
# loss: 0.258340  [51200/60000]
# loss: 0.339183  [57600/60000]
# Test Error:
#  Accuracy: 93.0%, Precision: 92.9%, Recall: 92.7%, F1: 92.1%, Avg loss: 0.250488
#
# Epoch 73
# -------------------------------
# loss: 0.184032  [    0/60000]
# loss: 0.224208  [ 6400/60000]
# loss: 0.165933  [12800/60000]
# loss: 0.299084  [19200/60000]
# loss: 0.197839  [25600/60000]
# loss: 0.286175  [32000/60000]
# loss: 0.175238  [38400/60000]
# loss: 0.345791  [44800/60000]
# loss: 0.256226  [51200/60000]
# loss: 0.337300  [57600/60000]
# Test Error:
#  Accuracy: 93.0%, Precision: 92.9%, Recall: 92.7%, F1: 92.1%, Avg loss: 0.249153
#
# Epoch 74
# -------------------------------
# loss: 0.182161  [    0/60000]
# loss: 0.223137  [ 6400/60000]
# loss: 0.164466  [12800/60000]
# loss: 0.297354  [19200/60000]
# loss: 0.196660  [25600/60000]
# loss: 0.284938  [32000/60000]
# loss: 0.174120  [38400/60000]
# loss: 0.344513  [44800/60000]
# loss: 0.254112  [51200/60000]
# loss: 0.335447  [57600/60000]
# Test Error:
#  Accuracy: 93.0%, Precision: 92.9%, Recall: 92.7%, F1: 92.1%, Avg loss: 0.247825
#
# Epoch 75
# -------------------------------
# loss: 0.180341  [    0/60000]
# loss: 0.222059  [ 6400/60000]
# loss: 0.163051  [12800/60000]
# loss: 0.295747  [19200/60000]
# loss: 0.195508  [25600/60000]
# loss: 0.283802  [32000/60000]
# loss: 0.172995  [38400/60000]
# loss: 0.343209  [44800/60000]
# loss: 0.252006  [51200/60000]
# loss: 0.333633  [57600/60000]
# Test Error:
#  Accuracy: 93.1%, Precision: 93.0%, Recall: 92.8%, F1: 92.2%, Avg loss: 0.246510
#
# Epoch 76
# -------------------------------
# loss: 0.178548  [    0/60000]
# loss: 0.220958  [ 6400/60000]
# loss: 0.161666  [12800/60000]
# loss: 0.294155  [19200/60000]
# loss: 0.194426  [25600/60000]
# loss: 0.282690  [32000/60000]
# loss: 0.171801  [38400/60000]
# loss: 0.341903  [44800/60000]
# loss: 0.249938  [51200/60000]
# loss: 0.331813  [57600/60000]
# Test Error:
#  Accuracy: 93.1%, Precision: 93.0%, Recall: 92.8%, F1: 92.2%, Avg loss: 0.245203
#
# Epoch 77
# -------------------------------
# loss: 0.176802  [    0/60000]
# loss: 0.219810  [ 6400/60000]
# loss: 0.160308  [12800/60000]
# loss: 0.292534  [19200/60000]
# loss: 0.193456  [25600/60000]
# loss: 0.281592  [32000/60000]
# loss: 0.170566  [38400/60000]
# loss: 0.340572  [44800/60000]
# loss: 0.247840  [51200/60000]
# loss: 0.330072  [57600/60000]
# Test Error:
#  Accuracy: 93.2%, Precision: 93.1%, Recall: 92.9%, F1: 92.3%, Avg loss: 0.243904
#
# Epoch 78
# -------------------------------
# loss: 0.175095  [    0/60000]
# loss: 0.218659  [ 6400/60000]
# loss: 0.158975  [12800/60000]
# loss: 0.290966  [19200/60000]
# loss: 0.192501  [25600/60000]
# loss: 0.280456  [32000/60000]
# loss: 0.169340  [38400/60000]
# loss: 0.339234  [44800/60000]
# loss: 0.245710  [51200/60000]
# loss: 0.328325  [57600/60000]
# Test Error:
#  Accuracy: 93.2%, Precision: 93.1%, Recall: 92.9%, F1: 92.3%, Avg loss: 0.242620
#
# Epoch 79
# -------------------------------
# loss: 0.173476  [    0/60000]
# loss: 0.217560  [ 6400/60000]
# loss: 0.157690  [12800/60000]
# loss: 0.289434  [19200/60000]
# loss: 0.191565  [25600/60000]
# loss: 0.279193  [32000/60000]
# loss: 0.168102  [38400/60000]
# loss: 0.337837  [44800/60000]
# loss: 0.243641  [51200/60000]
# loss: 0.326609  [57600/60000]
# Test Error:
#  Accuracy: 93.2%, Precision: 93.1%, Recall: 92.9%, F1: 92.3%, Avg loss: 0.241344
#
# Epoch 80
# -------------------------------
# loss: 0.171893  [    0/60000]
# loss: 0.216478  [ 6400/60000]
# loss: 0.156430  [12800/60000]
# loss: 0.287867  [19200/60000]
# loss: 0.190648  [25600/60000]
# loss: 0.277932  [32000/60000]
# loss: 0.166878  [38400/60000]
# loss: 0.336398  [44800/60000]
# loss: 0.241587  [51200/60000]
# loss: 0.324964  [57600/60000]
# Test Error:
#  Accuracy: 93.2%, Precision: 93.2%, Recall: 93.0%, F1: 92.4%, Avg loss: 0.240066
#
# Epoch 81
# -------------------------------
# loss: 0.170319  [    0/60000]
# loss: 0.215434  [ 6400/60000]
# loss: 0.155193  [12800/60000]
# loss: 0.286316  [19200/60000]
# loss: 0.189735  [25600/60000]
# loss: 0.276734  [32000/60000]
# loss: 0.165657  [38400/60000]
# loss: 0.334934  [44800/60000]
# loss: 0.239523  [51200/60000]
# loss: 0.323377  [57600/60000]
# Test Error:
#  Accuracy: 93.3%, Precision: 93.2%, Recall: 93.0%, F1: 92.4%, Avg loss: 0.238799
#
# Epoch 82
# -------------------------------
# loss: 0.168812  [    0/60000]
# loss: 0.214401  [ 6400/60000]
# loss: 0.153990  [12800/60000]
# loss: 0.284771  [19200/60000]
# loss: 0.188765  [25600/60000]
# loss: 0.275509  [32000/60000]
# loss: 0.164425  [38400/60000]
# loss: 0.333503  [44800/60000]
# loss: 0.237453  [51200/60000]
# loss: 0.321885  [57600/60000]
# Test Error:
#  Accuracy: 93.3%, Precision: 93.3%, Recall: 93.1%, F1: 92.5%, Avg loss: 0.237542
#
# Epoch 83
# -------------------------------
# loss: 0.167333  [    0/60000]
# loss: 0.213413  [ 6400/60000]
# loss: 0.152805  [12800/60000]
# loss: 0.283241  [19200/60000]
# loss: 0.187796  [25600/60000]
# loss: 0.274303  [32000/60000]
# loss: 0.163201  [38400/60000]
# loss: 0.332089  [44800/60000]
# loss: 0.235442  [51200/60000]
# loss: 0.320431  [57600/60000]
# Test Error:
#  Accuracy: 93.4%, Precision: 93.3%, Recall: 93.1%, F1: 92.5%, Avg loss: 0.236286
#
# Epoch 84
# -------------------------------
# loss: 0.165901  [    0/60000]
# loss: 0.212498  [ 6400/60000]
# loss: 0.151667  [12800/60000]
# loss: 0.281611  [19200/60000]
# loss: 0.186803  [25600/60000]
# loss: 0.273010  [32000/60000]
# loss: 0.162015  [38400/60000]
# loss: 0.330714  [44800/60000]
# loss: 0.233423  [51200/60000]
# loss: 0.319022  [57600/60000]
# Test Error:
#  Accuracy: 93.4%, Precision: 93.3%, Recall: 93.1%, F1: 92.5%, Avg loss: 0.235037
#
# Epoch 85
# -------------------------------
# loss: 0.164496  [    0/60000]
# loss: 0.211655  [ 6400/60000]
# loss: 0.150544  [12800/60000]
# loss: 0.280048  [19200/60000]
# loss: 0.185853  [25600/60000]
# loss: 0.271753  [32000/60000]
# loss: 0.160865  [38400/60000]
# loss: 0.329326  [44800/60000]
# loss: 0.231427  [51200/60000]
# loss: 0.317573  [57600/60000]
# Test Error:
#  Accuracy: 93.4%, Precision: 93.3%, Recall: 93.2%, F1: 92.6%, Avg loss: 0.233796
#
# Epoch 86
# -------------------------------
# loss: 0.163122  [    0/60000]
# loss: 0.210808  [ 6400/60000]
# loss: 0.149383  [12800/60000]
# loss: 0.278528  [19200/60000]
# loss: 0.184927  [25600/60000]
# loss: 0.270462  [32000/60000]
# loss: 0.159737  [38400/60000]
# loss: 0.327790  [44800/60000]
# loss: 0.229428  [51200/60000]
# loss: 0.316069  [57600/60000]
# Test Error:
#  Accuracy: 93.5%, Precision: 93.4%, Recall: 93.2%, F1: 92.6%, Avg loss: 0.232566
#
# Epoch 87
# -------------------------------
# loss: 0.161802  [    0/60000]
# loss: 0.209944  [ 6400/60000]
# loss: 0.148242  [12800/60000]
# loss: 0.277030  [19200/60000]
# loss: 0.183989  [25600/60000]
# loss: 0.269238  [32000/60000]
# loss: 0.158586  [38400/60000]
# loss: 0.326244  [44800/60000]
# loss: 0.227455  [51200/60000]
# loss: 0.314593  [57600/60000]
# Test Error:
#  Accuracy: 93.5%, Precision: 93.4%, Recall: 93.2%, F1: 92.6%, Avg loss: 0.231356
#
# Epoch 88
# -------------------------------
# loss: 0.160514  [    0/60000]
# loss: 0.209035  [ 6400/60000]
# loss: 0.147104  [12800/60000]
# loss: 0.275479  [19200/60000]
# loss: 0.183053  [25600/60000]
# loss: 0.268092  [32000/60000]
# loss: 0.157450  [38400/60000]
# loss: 0.324732  [44800/60000]
# loss: 0.225562  [51200/60000]
# loss: 0.313169  [57600/60000]
# Test Error:
#  Accuracy: 93.5%, Precision: 93.4%, Recall: 93.3%, F1: 92.7%, Avg loss: 0.230159
#
# Epoch 89
# -------------------------------
# loss: 0.159209  [    0/60000]
# loss: 0.208096  [ 6400/60000]
# loss: 0.145956  [12800/60000]
# loss: 0.273969  [19200/60000]
# loss: 0.182109  [25600/60000]
# loss: 0.266946  [32000/60000]
# loss: 0.156272  [38400/60000]
# loss: 0.323206  [44800/60000]
# loss: 0.223730  [51200/60000]
# loss: 0.311705  [57600/60000]
# Test Error:
#  Accuracy: 93.5%, Precision: 93.4%, Recall: 93.2%, F1: 92.7%, Avg loss: 0.228965
#
# Epoch 90
# -------------------------------
# loss: 0.157926  [    0/60000]
# loss: 0.207221  [ 6400/60000]
# loss: 0.144837  [12800/60000]
# loss: 0.272521  [19200/60000]
# loss: 0.181160  [25600/60000]
# loss: 0.265712  [32000/60000]
# loss: 0.155063  [38400/60000]
# loss: 0.321656  [44800/60000]
# loss: 0.221899  [51200/60000]
# loss: 0.310299  [57600/60000]
# Test Error:
#  Accuracy: 93.5%, Precision: 93.4%, Recall: 93.3%, F1: 92.7%, Avg loss: 0.227784
#
# Epoch 91
# -------------------------------
# loss: 0.156688  [    0/60000]
# loss: 0.206278  [ 6400/60000]
# loss: 0.143747  [12800/60000]
# loss: 0.271169  [19200/60000]
# loss: 0.180222  [25600/60000]
# loss: 0.264500  [32000/60000]
# loss: 0.153867  [38400/60000]
# loss: 0.320131  [44800/60000]
# loss: 0.219999  [51200/60000]
# loss: 0.308897  [57600/60000]
# Test Error:
#  Accuracy: 93.6%, Precision: 93.5%, Recall: 93.3%, F1: 92.7%, Avg loss: 0.226618
#
# Epoch 92
# -------------------------------
# loss: 0.155512  [    0/60000]
# loss: 0.205316  [ 6400/60000]
# loss: 0.142668  [12800/60000]
# loss: 0.269888  [19200/60000]
# loss: 0.179358  [25600/60000]
# loss: 0.263296  [32000/60000]
# loss: 0.152699  [38400/60000]
# loss: 0.318617  [44800/60000]
# loss: 0.218148  [51200/60000]
# loss: 0.307491  [57600/60000]
# Test Error:
#  Accuracy: 93.6%, Precision: 93.5%, Recall: 93.3%, F1: 92.8%, Avg loss: 0.225466
#
# Epoch 93
# -------------------------------
# loss: 0.154340  [    0/60000]
# loss: 0.204370  [ 6400/60000]
# loss: 0.141593  [12800/60000]
# loss: 0.268633  [19200/60000]
# loss: 0.178512  [25600/60000]
# loss: 0.262159  [32000/60000]
# loss: 0.151572  [38400/60000]
# loss: 0.317086  [44800/60000]
# loss: 0.216314  [51200/60000]
# loss: 0.306129  [57600/60000]
# Test Error:
#  Accuracy: 93.7%, Precision: 93.6%, Recall: 93.4%, F1: 92.8%, Avg loss: 0.224323
#
# Epoch 94
# -------------------------------
# loss: 0.153206  [    0/60000]
# loss: 0.203431  [ 6400/60000]
# loss: 0.140542  [12800/60000]
# loss: 0.267452  [19200/60000]
# loss: 0.177672  [25600/60000]
# loss: 0.261054  [32000/60000]
# loss: 0.150476  [38400/60000]
# loss: 0.315513  [44800/60000]
# loss: 0.214580  [51200/60000]
# loss: 0.304697  [57600/60000]
# Test Error:
#  Accuracy: 93.7%, Precision: 93.6%, Recall: 93.4%, F1: 92.9%, Avg loss: 0.223195
#
# Epoch 95
# -------------------------------
# loss: 0.152126  [    0/60000]
# loss: 0.202503  [ 6400/60000]
# loss: 0.139507  [12800/60000]
# loss: 0.266243  [19200/60000]
# loss: 0.176843  [25600/60000]
# loss: 0.259945  [32000/60000]
# loss: 0.149393  [38400/60000]
# loss: 0.313922  [44800/60000]
# loss: 0.212811  [51200/60000]
# loss: 0.303334  [57600/60000]
# Test Error:
#  Accuracy: 93.7%, Precision: 93.6%, Recall: 93.4%, F1: 92.9%, Avg loss: 0.222070
#
# Epoch 96
# -------------------------------
# loss: 0.151081  [    0/60000]
# loss: 0.201609  [ 6400/60000]
# loss: 0.138436  [12800/60000]
# loss: 0.265057  [19200/60000]
# loss: 0.175977  [25600/60000]
# loss: 0.258883  [32000/60000]
# loss: 0.148300  [38400/60000]
# loss: 0.312349  [44800/60000]
# loss: 0.211046  [51200/60000]
# loss: 0.302057  [57600/60000]
# Test Error:
#  Accuracy: 93.7%, Precision: 93.6%, Recall: 93.4%, F1: 92.9%, Avg loss: 0.220949
#
# Epoch 97
# -------------------------------
# loss: 0.150000  [    0/60000]
# loss: 0.200708  [ 6400/60000]
# loss: 0.137390  [12800/60000]
# loss: 0.263864  [19200/60000]
# loss: 0.175157  [25600/60000]
# loss: 0.257776  [32000/60000]
# loss: 0.147189  [38400/60000]
# loss: 0.310823  [44800/60000]
# loss: 0.209235  [51200/60000]
# loss: 0.300829  [57600/60000]
# Test Error:
#  Accuracy: 93.7%, Precision: 93.6%, Recall: 93.4%, F1: 92.9%, Avg loss: 0.219840
#
# Epoch 98
# -------------------------------
# loss: 0.148939  [    0/60000]
# loss: 0.199854  [ 6400/60000]
# loss: 0.136358  [12800/60000]
# loss: 0.262628  [19200/60000]
# loss: 0.174304  [25600/60000]
# loss: 0.256645  [32000/60000]
# loss: 0.146097  [38400/60000]
# loss: 0.309335  [44800/60000]
# loss: 0.207495  [51200/60000]
# loss: 0.299565  [57600/60000]
# Test Error:
#  Accuracy: 93.7%, Precision: 93.6%, Recall: 93.4%, F1: 92.9%, Avg loss: 0.218739
#
# Epoch 99
# -------------------------------
# loss: 0.147947  [    0/60000]
# loss: 0.198991  [ 6400/60000]
# loss: 0.135361  [12800/60000]
# loss: 0.261494  [19200/60000]
# loss: 0.173453  [25600/60000]
# loss: 0.255507  [32000/60000]
# loss: 0.145044  [38400/60000]
# loss: 0.307855  [44800/60000]
# loss: 0.205803  [51200/60000]
# loss: 0.298332  [57600/60000]
# Test Error:
#  Accuracy: 93.8%, Precision: 93.6%, Recall: 93.5%, F1: 92.9%, Avg loss: 0.217643
#
# Epoch 100
# -------------------------------
# loss: 0.146967  [    0/60000]
# loss: 0.198119  [ 6400/60000]
# loss: 0.134398  [12800/60000]
# loss: 0.260328  [19200/60000]
# loss: 0.172626  [25600/60000]
# loss: 0.254461  [32000/60000]
# loss: 0.143996  [38400/60000]
# loss: 0.306379  [44800/60000]
# loss: 0.204084  [51200/60000]
# loss: 0.297117  [57600/60000]
# Test Error:
#  Accuracy: 93.8%, Precision: 93.7%, Recall: 93.5%, F1: 92.9%, Avg loss: 0.216552
# Done!

# %%
import torch
from torch import nn, optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

def compute_metrics(preds, labels, num_classes):
    # 初始化混淆矩阵
    confusion_matrix = torch.zeros(num_classes, num_classes)
    for p, l in zip(preds, labels):
        confusion_matrix[l, p] += 1

    # 计算每个类的精确率和召回率
    precision = torch.diag(confusion_matrix) / confusion_matrix.sum(0)
    recall = torch.diag(confusion_matrix) / confusion_matrix.sum(1)

    # 计算F1-Score
    f1 = 2 * precision * recall / (precision + recall)

    # 计算总的准确率
    accuracy = torch.diag(confusion_matrix).sum() / confusion_matrix.sum()

    # 因为可能存在分母为0的情况，我们需要处理NaN值
    precision[precision != precision] = 0  # 将NaN替换为0
    recall[recall != recall] = 0
    f1[f1 != f1] = 0

    # 计算平均值
    precision_mean = precision.mean().item()
    recall_mean = recall.mean().item()
    f1_mean = f1.mean().item()

    return accuracy.item(), precision_mean, recall_mean, f1_mean


# RNN模型定义
class BasicRNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(BasicRNN, self).__init__()
        self.hidden_size = hidden_size
        self.i2h = nn.Linear(input_size + hidden_size, hidden_size)
        self.i2o = nn.Linear(input_size + hidden_size, output_size)
        self.relu = nn.ReLU()

    def forward(self, input, hidden):
        combined = torch.cat((input, hidden), 1)
        hidden = self.relu(self.i2h(combined))
        output = self.i2o(combined)
        return output, hidden

    def init_hidden(self, batch_size):
        return torch.zeros(batch_size, self.hidden_size)


# 数据加载和准备
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
train_data = datasets.FashionMNIST('F_MNIST_data', download=True, train=True, transform=transform)
trainloader = DataLoader(train_data, batch_size=64, shuffle=True)
test_data = datasets.FashionMNIST('F_MNIST_data', download=True, train=False, transform=transform)
testloader = DataLoader(test_data, batch_size=64, shuffle=True)

# 实例化模型、损失函数和优化器
input_size = 28
hidden_size = 128
output_size = 10
net = BasicRNN(input_size, hidden_size, output_size)
loss_rnn = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.003)

# 训练函数
def train_rnn(model, trainloader, criterion, optimizer, epochs):
    total_loss = 0
    for images, labels in trainloader:
        optimizer.zero_grad()
        hidden = model.init_hidden(images.shape[0])
        images = images.squeeze().view(-1, 28, 28)  # (batch_size, seq_len, input_size)
        for i in range(images.shape[1]):
            output, hidden = net(images[:, i, :], hidden)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    total_loss /= len(trainloader)
    print(f' Loss: {total_loss:.4f}')
    return total_loss




# 测试函数
def test_rnn(model, testloader,criterion):
    accuracy_all, precision_all, recall_all, f1_all, total_loss = 0, 0, 0, 0, 0
    with torch.no_grad():
        for images, labels in testloader:
            hidden = model.init_hidden(images.shape[0])
            images = images.squeeze().view(-1, 28, 28)
            for i in range(images.shape[1]):
                output, hidden = model(images[:, i, :], hidden)
            loss = criterion(output, labels).item()
            output=torch.argmax(output,dim=1)
            total_loss += loss
            accuracy, precision_mean, recall_mean, f1_mean = compute_metrics(output, labels, num_classes=10)
            accuracy_all += accuracy
            precision_all += precision_mean
            recall_all += recall_mean
            f1_all += f1_mean
        accuracy_all/= len(testloader)
        precision_all/= len(testloader)
        recall_all/= len(testloader)
        f1_all/= len(testloader)
        loss=total_loss/len(testloader)
        print(f'Accuracy: {accuracy_all:.4f}, Precision: {precision_all:.4f}, Recall: {recall_all:.4f}, F1: {f1_all:.4f}')
        return loss, accuracy_all, precision_all, recall_all, f1_all

train_losses = []
test_losses = []
accuracy_all = []
precision_all = []
recall_all = []
f1_all = []

# 训练模型
epochs = 100


for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loss=train_rnn(net, trainloader, loss_rnn, optimizer, epochs)
    test_loss,accuracy,precision,recall,f1=test_rnn(net, testloader,loss_rnn)
    # 收集每个epoch的训练损失和测试损失
    train_losses.append(train_loss)
    test_losses.append(test_loss)
    accuracy_all.append(accuracy)
    precision_all.append(precision)
    recall_all.append(recall)
    f1_all.append(f1)

# 绘出指标变化图
import matplotlib.pyplot as plt
epochs = range(1, len(train_losses) + 1)

plt.figure(figsize=(10, 6))

plt.plot(epochs, accuracy_all, label='Accuracy', marker='o', linestyle='-')
plt.plot(epochs, precision_all, label='Precision', marker='s', linestyle='--')
plt.plot(epochs, recall_all, label='Recall', marker='^', linestyle='-.')
plt.plot(epochs, f1_all, label='F1 Score', marker='*', linestyle=':')

plt.title('Model Performance Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Metric')
plt.legend()
plt.grid(True)
plt.show()


# 绘出损失变化图
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_losses, label='Train')
plt.plot(epochs, test_losses, label='Test')
plt.title('Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

print("Done!")
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to F_MNIST_data\FashionMNIST\raw\train-images-idx3-ubyte.gz
# 100%|██████████████████████████████████████████████████████████████████| 26421880/26421880 [00:41<00:00, 639497.75it/s]
# Extracting F_MNIST_data\FashionMNIST\raw\train-images-idx3-ubyte.gz to F_MNIST_data\FashionMNIST\raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to F_MNIST_data\FashionMNIST\raw\train-labels-idx1-ubyte.gz
# 100%|████████████████████████████████████████████████████████████████████████| 29515/29515 [00:00<00:00, 139831.61it/s]
# Extracting F_MNIST_data\FashionMNIST\raw\train-labels-idx1-ubyte.gz to F_MNIST_data\FashionMNIST\raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to F_MNIST_data\FashionMNIST\raw\t10k-images-idx3-ubyte.gz
# 100%|███████████████████████████████████████████████████████████████████| 4422102/4422102 [00:02<00:00, 1962799.85it/s]
# Extracting F_MNIST_data\FashionMNIST\raw\t10k-images-idx3-ubyte.gz to F_MNIST_data\FashionMNIST\raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to F_MNIST_data\FashionMNIST\raw\t10k-labels-idx1-ubyte.gz
# 100%|█████████████████████████████████████████████████████████████████████████| 5148/5148 [00:00<00:00, 5088917.51it/s]
# Extracting F_MNIST_data\FashionMNIST\raw\t10k-labels-idx1-ubyte.gz to F_MNIST_data\FashionMNIST\raw
#
# Epoch 1
# -------------------------------
#  Loss: 0.8641
# Accuracy: 0.7683, Precision: 0.7748, Recall: 0.7673, F1: 0.7533
# Epoch 2
# -------------------------------
#  Loss: 0.5984
# Accuracy: 0.8047, Precision: 0.8128, Recall: 0.8039, F1: 0.7923
# Epoch 3
# -------------------------------
#  Loss: 0.5512
# Accuracy: 0.7992, Precision: 0.8016, Recall: 0.7968, F1: 0.7833
# Epoch 4
# -------------------------------
#  Loss: 0.5137
# Accuracy: 0.8184, Precision: 0.8163, Recall: 0.8170, F1: 0.7994
# Epoch 5
# -------------------------------
#  Loss: 0.5093
# Accuracy: 0.8134, Precision: 0.8158, Recall: 0.8135, F1: 0.7958
# Epoch 6
# -------------------------------
#  Loss: 0.4797
# Accuracy: 0.8315, Precision: 0.8331, Recall: 0.8291, F1: 0.8182
# Epoch 7
# -------------------------------
#  Loss: 0.6463
# Accuracy: 0.8139, Precision: 0.8121, Recall: 0.8113, F1: 0.7971
# Epoch 8
# -------------------------------
#  Loss: 0.5653
# Accuracy: 0.8133, Precision: 0.8161, Recall: 0.8122, F1: 0.7997
# Epoch 9
# -------------------------------
#  Loss: 0.5034
# Accuracy: 0.7979, Precision: 0.7973, Recall: 0.7937, F1: 0.7781
# Epoch 10
# -------------------------------
#  Loss: 0.4836
# Accuracy: 0.8199, Precision: 0.8198, Recall: 0.8175, F1: 0.8053
# Epoch 11
# -------------------------------
#  Loss: 0.5807
# Accuracy: 0.7866, Precision: 0.7969, Recall: 0.7839, F1: 0.7680
# Epoch 12
# -------------------------------
#  Loss: 0.4781
# Accuracy: 0.8247, Precision: 0.8242, Recall: 0.8235, F1: 0.8099
# Epoch 13
# -------------------------------
#  Loss: 0.5047
# Accuracy: 0.8221, Precision: 0.8172, Recall: 0.8179, F1: 0.8034
# Epoch 14
# -------------------------------
#  Loss: 0.7861
# Accuracy: 0.7689, Precision: 0.7682, Recall: 0.7683, F1: 0.7445
# Epoch 15
# -------------------------------
#  Loss: 0.5689
# Accuracy: 0.7892, Precision: 0.7898, Recall: 0.7835, F1: 0.7701
# Epoch 16
# -------------------------------
#  Loss: 0.5226
# Accuracy: 0.7984, Precision: 0.8093, Recall: 0.7986, F1: 0.7860
# Epoch 17
# -------------------------------
#  Loss: 0.4987
# Accuracy: 0.8251, Precision: 0.8249, Recall: 0.8221, F1: 0.8073
# Epoch 18
# -------------------------------
#  Loss: 1.1312
# Accuracy: 0.5927, Precision: 0.5904, Recall: 0.5912, F1: 0.5535
# Epoch 19
# -------------------------------
#  Loss: 0.8661
# Accuracy: 0.7162, Precision: 0.7131, Recall: 0.7154, F1: 0.6926
# Epoch 20
# -------------------------------
#  Loss: 0.7440
# Accuracy: 0.7318, Precision: 0.7343, Recall: 0.7334, F1: 0.7140
# Epoch 21
# -------------------------------
#  Loss: 0.6929
# Accuracy: 0.7425, Precision: 0.7497, Recall: 0.7429, F1: 0.7240
# Epoch 22
# -------------------------------
#  Loss: 0.6748
# Accuracy: 0.7419, Precision: 0.7436, Recall: 0.7367, F1: 0.7171
# Epoch 23
# -------------------------------
#  Loss: 0.6833
# Accuracy: 0.7584, Precision: 0.7624, Recall: 0.7589, F1: 0.7406
# Epoch 24
# -------------------------------
#  Loss: 0.9482
# Accuracy: 0.7041, Precision: 0.7090, Recall: 0.7038, F1: 0.6805
# Epoch 25
# -------------------------------
#  Loss: 0.8157
# Accuracy: 0.6829, Precision: 0.6873, Recall: 0.6796, F1: 0.6566
# Epoch 26
# -------------------------------
#  Loss: 0.7329
# Accuracy: 0.7731, Precision: 0.7738, Recall: 0.7718, F1: 0.7563
# Epoch 27
# -------------------------------
#  Loss: 0.6166
# Accuracy: 0.7889, Precision: 0.7844, Recall: 0.7863, F1: 0.7665
# Epoch 28
# -------------------------------
#  Loss: 0.5824
# Accuracy: 0.7666, Precision: 0.7694, Recall: 0.7648, F1: 0.7437
# Epoch 29
# -------------------------------
#  Loss: 0.6458
# Accuracy: 0.7929, Precision: 0.7995, Recall: 0.7939, F1: 0.7786
# Epoch 30
# -------------------------------
#  Loss: 0.5900
# Accuracy: 0.7860, Precision: 0.7800, Recall: 0.7852, F1: 0.7677
# Epoch 31
# -------------------------------
#  Loss: 0.6434
# Accuracy: 0.6791, Precision: 0.7006, Recall: 0.6758, F1: 0.6549
# Epoch 32
# -------------------------------
#  Loss: 0.6855
# Accuracy: 0.7916, Precision: 0.7964, Recall: 0.7908, F1: 0.7786
# Epoch 33
# -------------------------------
#  Loss: 0.6031
# Accuracy: 0.7714, Precision: 0.7787, Recall: 0.7705, F1: 0.7563
# Epoch 34
# -------------------------------
#  Loss: 1.3804
# Accuracy: 0.5669, Precision: 0.5764, Recall: 0.5664, F1: 0.5292
# Epoch 35
# -------------------------------
#  Loss: 1.0495
# Accuracy: 0.6378, Precision: 0.6482, Recall: 0.6379, F1: 0.6147
# Epoch 36
# -------------------------------
#  Loss: 0.9441
# Accuracy: 0.6644, Precision: 0.6678, Recall: 0.6641, F1: 0.6435
# Epoch 37
# -------------------------------
#  Loss: 0.9125
# Accuracy: 0.6582, Precision: 0.6633, Recall: 0.6557, F1: 0.6277
# Epoch 38
# -------------------------------
#  Loss: 0.8714
# Accuracy: 0.6458, Precision: 0.6573, Recall: 0.6457, F1: 0.6242
# Epoch 39
# -------------------------------
#  Loss: 1.4063
# Accuracy: 0.5723, Precision: 0.5629, Recall: 0.5677, F1: 0.5280
# Epoch 40
# -------------------------------
#  Loss: 1.0515
# Accuracy: 0.6283, Precision: 0.6365, Recall: 0.6288, F1: 0.6089
# Epoch 41
# -------------------------------
#  Loss: 0.9473
# Accuracy: 0.6581, Precision: 0.6558, Recall: 0.6590, F1: 0.6347
# Epoch 42
# -------------------------------
#  Loss: 0.8242
# Accuracy: 0.7077, Precision: 0.7091, Recall: 0.7021, F1: 0.6727
# Epoch 43
# -------------------------------
#  Loss: 0.7378
# Accuracy: 0.7526, Precision: 0.7580, Recall: 0.7534, F1: 0.7379
# Epoch 44
# -------------------------------
#  Loss: 0.7300
# Accuracy: 0.6999, Precision: 0.7004, Recall: 0.7030, F1: 0.6704
# Epoch 45
# -------------------------------
#  Loss: 0.7004
# Accuracy: 0.7325, Precision: 0.7459, Recall: 0.7336, F1: 0.7163
# Epoch 46
# -------------------------------
#  Loss: 0.6490
# Accuracy: 0.7736, Precision: 0.7761, Recall: 0.7702, F1: 0.7549
# Epoch 47
# -------------------------------
#  Loss: 0.6104
# Accuracy: 0.7814, Precision: 0.7832, Recall: 0.7805, F1: 0.7623
# Epoch 48
# -------------------------------
#  Loss: 0.5868
# Accuracy: 0.7827, Precision: 0.7927, Recall: 0.7791, F1: 0.7669
# Epoch 49
# -------------------------------
#  Loss: 0.8071
# Accuracy: 0.5946, Precision: 0.6014, Recall: 0.5966, F1: 0.5698
# Epoch 50
# -------------------------------
#  Loss: 1.4362
# Accuracy: 0.4803, Precision: 0.4887, Recall: 0.4787, F1: 0.4542
# Epoch 51
# -------------------------------
#  Loss: 2.3506
# Accuracy: 0.5534, Precision: 0.5504, Recall: 0.5529, F1: 0.5214
# Epoch 52
# -------------------------------
#  Loss: 1.3943
# Accuracy: 0.4640, Precision: 0.4615, Recall: 0.4627, F1: 0.4312
# Epoch 53
# -------------------------------
#  Loss: 1.5082
# Accuracy: 0.5876, Precision: 0.5823, Recall: 0.5848, F1: 0.5516
# Epoch 54
# -------------------------------
#  Loss: 1.1681
# Accuracy: 0.5876, Precision: 0.6090, Recall: 0.5864, F1: 0.5584
# Epoch 55
# -------------------------------
#  Loss: 1.7013
# Accuracy: 0.5310, Precision: 0.5049, Recall: 0.5289, F1: 0.4800
# Epoch 56
# -------------------------------
#  Loss: 1.2078
# Accuracy: 0.5720, Precision: 0.5727, Recall: 0.5730, F1: 0.5375
# Epoch 57
# -------------------------------
#  Loss: 1.0873
# Accuracy: 0.5732, Precision: 0.5752, Recall: 0.5688, F1: 0.5328
# Epoch 58
# -------------------------------
#  Loss: 1.0335
# Accuracy: 0.6009, Precision: 0.6109, Recall: 0.6009, F1: 0.5532
# Epoch 59
# -------------------------------
#  Loss: 0.9735
# Accuracy: 0.6502, Precision: 0.6530, Recall: 0.6544, F1: 0.6244
# Epoch 60
# -------------------------------
#  Loss: 0.9372
# Accuracy: 0.6196, Precision: 0.5798, Recall: 0.6184, F1: 0.5700
# Epoch 61
# -------------------------------
#  Loss: 1.0023
# Accuracy: 0.6481, Precision: 0.6552, Recall: 0.6435, F1: 0.6239
# Epoch 62
# -------------------------------
#  Loss: 0.8444
# Accuracy: 0.7162, Precision: 0.7177, Recall: 0.7175, F1: 0.6967
# Epoch 63
# -------------------------------
#  Loss: 0.7945
# Accuracy: 0.7243, Precision: 0.7256, Recall: 0.7219, F1: 0.7071
# Epoch 64
# -------------------------------
#  Loss: 0.7411
# Accuracy: 0.6950, Precision: 0.7046, Recall: 0.6913, F1: 0.6681
# Epoch 65
# -------------------------------
#  Loss: 2.0033
# Accuracy: 0.4440, Precision: 0.4500, Recall: 0.4441, F1: 0.4173
# Epoch 66
# -------------------------------
#  Loss: 1.3602
# Accuracy: 0.5591, Precision: 0.5528, Recall: 0.5596, F1: 0.5216
# Epoch 67
# -------------------------------
#  Loss: 1.2169
# Accuracy: 0.5190, Precision: 0.5157, Recall: 0.5176, F1: 0.4873
# Epoch 68
# -------------------------------
#  Loss: 1.2633
# Accuracy: 0.5107, Precision: 0.4761, Recall: 0.5067, F1: 0.4544
# Epoch 69
# -------------------------------
#  Loss: 1.1691
# Accuracy: 0.5889, Precision: 0.5849, Recall: 0.5879, F1: 0.5612
# Epoch 70
# -------------------------------
#  Loss: 1.0834
# Accuracy: 0.6108, Precision: 0.6124, Recall: 0.6075, F1: 0.5830
# Epoch 71
# -------------------------------
#  Loss: 0.9873
# Accuracy: 0.6337, Precision: 0.6484, Recall: 0.6326, F1: 0.6075
# Epoch 72
# -------------------------------
#  Loss: 0.8919
# Accuracy: 0.6804, Precision: 0.6842, Recall: 0.6752, F1: 0.6529
# Epoch 73
# -------------------------------
#  Loss: 0.8821
# Accuracy: 0.6405, Precision: 0.6357, Recall: 0.6403, F1: 0.6081
# Epoch 74
# -------------------------------
#  Loss: 0.8976
# Accuracy: 0.6893, Precision: 0.6880, Recall: 0.6884, F1: 0.6685
# Epoch 75
# -------------------------------
#  Loss: 0.7911
# Accuracy: 0.7048, Precision: 0.7019, Recall: 0.7062, F1: 0.6787
# Epoch 76
# -------------------------------
#  Loss: 0.7717
# Accuracy: 0.7198, Precision: 0.7175, Recall: 0.7209, F1: 0.6994
# Epoch 77
# -------------------------------
#  Loss: 0.7489
# Accuracy: 0.6202, Precision: 0.6360, Recall: 0.6213, F1: 0.5965
# Epoch 78
# -------------------------------
#  Loss: 0.9260
# Accuracy: 0.6598, Precision: 0.6759, Recall: 0.6565, F1: 0.6269
# Epoch 79
# -------------------------------
#  Loss: 0.8925
# Accuracy: 0.7028, Precision: 0.7046, Recall: 0.7009, F1: 0.6770
# Epoch 80
# -------------------------------
#  Loss: 0.9354
# Accuracy: 0.6717, Precision: 0.6713, Recall: 0.6702, F1: 0.6480
# Epoch 81
# -------------------------------
#  Loss: 0.7917
# Accuracy: 0.7205, Precision: 0.7241, Recall: 0.7185, F1: 0.7006
# Epoch 82
# -------------------------------
#  Loss: 0.7308
# Accuracy: 0.7279, Precision: 0.7291, Recall: 0.7296, F1: 0.7065
# Epoch 83
# -------------------------------
#  Loss: 0.7058
# Accuracy: 0.7416, Precision: 0.7480, Recall: 0.7411, F1: 0.7277
# Epoch 84
# -------------------------------
#  Loss: 0.6731
# Accuracy: 0.7516, Precision: 0.7530, Recall: 0.7502, F1: 0.7338
# Epoch 85
# -------------------------------
#  Loss: 0.6508
# Accuracy: 0.7586, Precision: 0.7550, Recall: 0.7565, F1: 0.7391
# Epoch 86
# -------------------------------
#  Loss: 0.6690
# Accuracy: 0.7661, Precision: 0.7617, Recall: 0.7650, F1: 0.7472
# Epoch 87
# -------------------------------
#  Loss: 0.6947
# Accuracy: 0.7244, Precision: 0.7282, Recall: 0.7242, F1: 0.7022
# Epoch 88
# -------------------------------
#  Loss: 0.9625
# Accuracy: 0.7135, Precision: 0.7149, Recall: 0.7128, F1: 0.6924
# Epoch 89
# -------------------------------
#  Loss: 1.1342
# Accuracy: 0.7197, Precision: 0.7188, Recall: 0.7194, F1: 0.6955
# Epoch 90
# -------------------------------
#  Loss: 0.7112
# Accuracy: 0.7420, Precision: 0.7405, Recall: 0.7411, F1: 0.7232
# Epoch 91
# -------------------------------
#  Loss: 0.7124
# Accuracy: 0.7457, Precision: 0.7462, Recall: 0.7470, F1: 0.7255
# Epoch 92
# -------------------------------
#  Loss: 1.3088
# Accuracy: 0.6085, Precision: 0.6237, Recall: 0.6061, F1: 0.5849
# Epoch 93
# -------------------------------
#  Loss: 1.3777
# Accuracy: 0.4911, Precision: 0.5041, Recall: 0.4910, F1: 0.4533
# Epoch 94
# -------------------------------
#  Loss: 1.2208
# Accuracy: 0.4591, Precision: 0.4957, Recall: 0.4595, F1: 0.4270
# Epoch 95
# -------------------------------
#  Loss: 1.2446
# Accuracy: 0.5532, Precision: 0.5479, Recall: 0.5476, F1: 0.5173
# Epoch 96
# -------------------------------
#  Loss: 1.2375
# Accuracy: 0.4141, Precision: 0.4376, Recall: 0.4129, F1: 0.3684
# Epoch 97
# -------------------------------
#  Loss: 1.1760
# Accuracy: 0.5511, Precision: 0.5206, Recall: 0.5510, F1: 0.5058
# Epoch 98
# -------------------------------
#  Loss: 1.1049
# Accuracy: 0.6062, Precision: 0.6042, Recall: 0.6043, F1: 0.5817
# Epoch 99
# -------------------------------
#  Loss: 1.0278
# Accuracy: 0.6457, Precision: 0.6415, Recall: 0.6433, F1: 0.6149
# Epoch 100
# -------------------------------
#  Loss: 0.9723
# Accuracy: 0.6369, Precision: 0.6496, Recall: 0.6375, F1: 0.6142
# Done!
